# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Regression Problem : diamond price prediction

# %% [markdown]
# ### Loading the DATA

# %%
df = pd.read_csv("diamonds.csv")
df
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
df.shape
# Out:
# (53940, 10)

# %% [markdown]
# ### EDA

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53940 non-null  float64
#  1   cut      53940 non-null  object
#  2   color    53940 non-null  object
#  3   clarity  53940 non-null  object
#  4   depth    53940 non-null  float64
#  5   table    53940 non-null  float64
#  6   price    53940 non-null  int64
#  7   x        53940 non-null  float64
#  8   y        53940 non-null  float64
#  9   z        53940 non-null  float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 4.1+ MB

# %%
df.isna().sum()

# if missing values in numeric : use mean,median
# if missing values in categorical : mode
# Out:
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# price      0
# x          0
# y          0
# z          0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 53935    False
# 53936    False
# 53937    False
# 53938    False
# 53939    False
# Length: 53940, dtype: bool

# %%
df.duplicated().sum()
# Out:
# np.int64(146)

# %%
df = df.drop_duplicates()
df
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53794 rows x 10 columns]

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.describe()
# Out:
#              carat         depth         table         price             x  \
# count  53794.00000  53794.000000  53794.000000  53794.000000  53794.000000
# mean       0.79778     61.748080     57.458109   3933.065082      5.731214
# std        0.47339      1.429909      2.233679   3988.114460      1.120695
# min        0.20000     43.000000     43.000000    326.000000      0.000000
# 25%        0.40000     61.000000     56.000000    951.000000      4.710000
# 50%        0.70000     61.800000     57.000000   2401.000000      5.700000
# 75%        1.04000     62.500000     59.000000   5326.750000      6.540000
# max        5.01000     79.000000     95.000000  18823.000000     10.740000
#
#                   y             z
# count  53794.000000  53794.000000
# mean       5.734653      3.538714
# std        1.141209      0.705037
# min        0.000000      0.000000
# 25%        4.720000      2.910000
# 50%        5.710000      3.530000
# 75%        6.540000      4.030000
# ...

# %%
df.describe(include='all')
# Out:
#               carat    cut  color clarity         depth         table  \
# count   53794.00000  53794  53794   53794  53794.000000  53794.000000
# unique          NaN      5      7       8           NaN           NaN
# top             NaN  Ideal      G     SI1           NaN           NaN
# freq            NaN  21488  11262   13032           NaN           NaN
# mean        0.79778    NaN    NaN     NaN     61.748080     57.458109
# std         0.47339    NaN    NaN     NaN      1.429909      2.233679
# min         0.20000    NaN    NaN     NaN     43.000000     43.000000
# 25%         0.40000    NaN    NaN     NaN     61.000000     56.000000
# 50%         0.70000    NaN    NaN     NaN     61.800000     57.000000
# 75%         1.04000    NaN    NaN     NaN     62.500000     59.000000
# max         5.01000    NaN    NaN     NaN     79.000000     95.000000
#
#                price             x             y             z
# count   53794.000000  53794.000000  53794.000000  53794.000000
# ...

# %%
df.describe(percentiles=[0.05,0.10,0.15,0.2,0.25,0.50,0.75,0.80,0.85,0.90,0.95])
# Out:
#              carat         depth         table         price             x  \
# count  53794.00000  53794.000000  53794.000000  53794.000000  53794.000000
# mean       0.79778     61.748080     57.458109   3933.065082      5.731214
# std        0.47339      1.429909      2.233679   3988.114460      1.120695
# min        0.20000     43.000000     43.000000    326.000000      0.000000
# 5%         0.30000     59.300000     54.000000    544.000000      4.290000
# 10%        0.31000     60.000000     55.000000    646.000000      4.360000
# 15%        0.32000     60.500000     55.000000    737.000000      4.420000
# 20%        0.35000     60.800000     56.000000    837.000000      4.540000
# 25%        0.40000     61.000000     56.000000    951.000000      4.710000
# 50%        0.70000     61.800000     57.000000   2401.000000      5.700000
# 75%        1.04000     62.500000     59.000000   5326.750000      6.540000
# ...

# %%
df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %% [markdown]
# ### Finding the associations between variables and target

# %%
import seaborn as sns

# %%
# numeric feature vs numeric target  ==> scatorplot

sns.pairplot(data=df , x_vars= [ 'carat','depth', 'table', 'x','y','z'], y_vars=['price'])

# %%
# categorical features vs numeric target ==> Boxplot

sns.boxplot(data=df , x='price' , hue='cut')
# Out:
# <Axes: xlabel='price'>

# %%
sns.boxplot(data=df , x= 'price' , hue='color')


# from this we can say as color changes price changes
# Out:
# <Axes: xlabel='price'>

# %%
sns.boxplot(data=df , y= 'price' , hue='clarity')
# Out:
# <Axes: ylabel='price'>

# %% [markdown]
# ## Segregate the data into features and target

# %%
x = df.drop('price' , axis=1)
y = df['price']

print(x.shape)
print(y.shape)
# Out:
# (53794, 9)
# (53794,)

# %% [markdown]
# ### Split the data into trainging and testing

# %%
from sklearn.model_selection import train_test_split

# %%
x_train , x_test , y_train , y_test = train_test_split(x,y,train_size=0.8 , random_state=42)

x_train.shape , x_test.shape , y_train.shape , y_test.shape
# Out:
# ((43035, 9), (10759, 9), (43035,), (10759,))

# %% [markdown]
# ## (Train) Data Preprocessing

# %%
# categorical Encoding ==> Ordinal Encoding

from sklearn.preprocessing import OrdinalEncoder

# %%
df['cut'].unique()
# Out:
# array(['Ideal', 'Premium', 'Good', 'Very Good', 'Fair'], dtype=object)

# %%
df['color'].unique()
# Out:
# array(['E', 'I', 'J', 'H', 'F', 'G', 'D'], dtype=object)

# %%
df['clarity'].unique()
# Out:
# array(['SI2', 'SI1', 'VS1', 'VS2', 'VVS2', 'VVS1', 'I1', 'IF'],
#       dtype=object)

# %%
## Ordinal Encoding 

# CUt 
cut_order = ['Fair' , 'Good', 'Very Good', 'Premium', 'Ideal' ]

# Color
color_order = ['D','E','F','G','H','I','J']

# CLarity
clarity_order = ['I1','SI1','SI2','VS1','VS2','VVS1','VVS2','IF']

# object
oe = OrdinalEncoder(categories=[cut_order , color_order , clarity_order])

oe
# Out:
# OrdinalEncoder(categories=[['Fair', 'Good', 'Very Good', 'Premium', 'Ideal'],
#                            ['D', 'E', 'F', 'G', 'H', 'I', 'J'],
#                            ['I1', 'SI1', 'SI2', 'VS1', 'VS2', 'VVS1', 'VVS2',
#                             'IF']])

# %%
# scaling

from sklearn.preprocessing import RobustScaler

# %%
### Robust Scaler

scaler = RobustScaler()
scaler
# Out:
# RobustScaler()

# %%
 ## Column Transformer

from sklearn.compose import ColumnTransformer

# %%
ct = ColumnTransformer(
    [
        ('ORDINAL' , oe , ['cut','color','clarity']),
        ('Scale', scaler , ['carat' , 'depth' , 'table' , 'x','y','z'])
    ], remainder='passthrough'
    ,verbose_feature_names_out=False
).set_output(transform='pandas')

ct
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('ORDINAL',
#                                  OrdinalEncoder(categories=[['Fair', 'Good',
#                                                              'Very Good',
#                                                              'Premium',
#                                                              'Ideal'],
#                                                             ['D', 'E', 'F', 'G',
#                                                              'H', 'I', 'J'],
#                                                             ['I1', 'SI1', 'SI2',
#                                                              'VS1', 'VS2',
#                                                              'VVS1', 'VVS2',
#                                                              'IF']]),
#                                  ['cut', 'color', 'clarity']),
#                                 ('Scale', RobustScaler(),
# ...

# %%
x_train_transformed = ct.fit_transform(x_train)
x_train_transformed.head()
# Out:
#        cut  color  clarity     carat     depth     table         x         y  \
# 33544  4.0    0.0      4.0 -0.546875  0.133333 -0.666667 -0.666667 -0.648352
# 26752  4.0    0.0      2.0  2.359375  0.133333  0.000000  1.459016  1.428571
# 45914  4.0    1.0      4.0 -0.265625 -1.200000  0.000000 -0.245902 -0.225275
# 3071   3.0    0.0      1.0  0.156250 -0.066667  0.333333  0.147541  0.120879
# 43829  4.0    1.0      5.0 -0.453125 -0.200000 -0.333333 -0.480874 -0.489011
#
#               z
# 33544 -0.646018
# 26752  1.469027
# 45914 -0.318584
# 3071   0.132743
# 43829 -0.495575

# %%
x_train_transformed.min()
# Out:
# cut         0.000000
# color       0.000000
# clarity     0.000000
# carat      -0.781250
# depth     -12.533333
# table      -4.666667
# x          -3.109290
# y          -3.137363
# z          -3.115044
# dtype: float64

# %%
x_train_transformed.max()
# Out:
# cut         4.000000
# color       6.000000
# clarity     7.000000
# carat       6.734375
# depth      11.466667
# table      12.666667
# x           2.759563
# y          29.225275
# z           4.017699
# dtype: float64

# %% [markdown]
# # Model Building

# %% [markdown]
# ## Regression
# - KNN
# - Destance Tree
# - Linear Regression
# - SVRX
# - Random Forest
#
#
#    ### ENSEMBLES
#     - Ada Boost
#     - Grad Boosting
#     - XG Boost

# %%
## Model Building

from sklearn.neighbors import KNeighborsRegressor

# %%
knn = KNeighborsRegressor()
knn
# Out:
# KNeighborsRegressor()

# %%
knn.fit(x_train_transformed , y_train)
# Out:
# KNeighborsRegressor()

# %%
knn.score(x_train_transformed , y_train)

# r2 score
# Out:
# 0.9744445939450368

# %%
# Descion Tree

from sklearn.tree import DecisionTreeRegressor

# %%
dt = DecisionTreeRegressor()
dt
# Out:
# DecisionTreeRegressor()

# %%
dt.fit(x_train_transformed , y_train)
# Out:
# DecisionTreeRegressor()

# %%
dt.score(x_train_transformed , y_train)
# Out:
# 0.9999972338407894

# %%
## (Test) Data Proprocessing

x_test_transformed= ct.transform(x_test)
x_test_transformed
# Out:
#        cut  color  clarity     carat     depth     table         x         y  \
# 43657  0.0    6.0      4.0  0.015625  2.066667 -1.000000 -0.032787 -0.098901
# 4274   2.0    1.0      2.0  0.312500 -0.533333  0.666667  0.245902  0.258242
# 47412  4.0    3.0      3.0 -0.203125  0.200000 -0.333333 -0.213115 -0.208791
# 44437  3.0    1.0      4.0 -0.296875  0.466667  1.000000 -0.333333 -0.335165
# 13975  4.0    5.0      1.0  0.765625  0.333333 -0.666667  0.606557  0.609890
# ...    ...    ...      ...       ...       ...       ...       ...       ...
# 41789  3.0    3.0      1.0 -0.281250  0.533333  0.333333 -0.306011 -0.335165
# 43542  4.0    3.0      4.0 -0.281250 -0.066667 -0.333333 -0.295082 -0.285714
# 35783  4.0    2.0      5.0 -0.593750 -0.200000 -0.333333 -0.699454 -0.703297
# 25885  3.0    1.0      4.0  1.312500  0.333333  0.333333  0.885246  0.923077
# 39329  3.0    1.0      5.0 -0.546875  0.800000  0.666667 -0.661202 -0.697802
#
#               z
# 43657  0.088496
# ...

# %% [markdown]
# ### Performance Evalution

# %%
from sklearn.metrics import r2_score

# %%
# Decision Tree

y_pred = dt.predict(x_test_transformed)
y_pred
# Out:
# array([ 1774.,  3621.,  1822., ...,   867., 14578.,  1044.],
#       shape=(10759,))

# %%
r2_score(y_pred , y_test)
# Out:
# 0.9675692951358006

# %%
# KNN

y_pred_knn = knn.predict(x_test_transformed)
r2_score(y_pred_knn , y_test)
# Out:
# 0.9563725512907589
