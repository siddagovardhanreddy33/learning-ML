# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('placement.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  100 non-null    int64
#  1   cgpa        100 non-null    float64
#  2   iq          100 non-null    float64
#  3   placement   100 non-null    int64
# dtypes: float64(2), int64(2)
# memory usage: 3.3 KB

# %%
df.head()
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1
# 4           4   5.8  142.0          0

# %%
df.tail()
# Out:
#     Unnamed: 0  cgpa     iq  placement
# 95          95   4.3  200.0          0
# 96          96   4.4   42.0          0
# 97          97   6.7  182.0          1
# 98          98   6.3  103.0          1
# 99          99   6.2  113.0          1

# %%
df.shape
# Out:
# (100, 4)

# %%
df
# Out:
#     Unnamed: 0  cgpa     iq  placement
# 0            0   6.8  123.0          1
# 1            1   5.9  106.0          0
# 2            2   5.3  121.0          0
# 3            3   7.4  132.0          1
# 4            4   5.8  142.0          0
# ..         ...   ...    ...        ...
# 95          95   4.3  200.0          0
# 96          96   4.4   42.0          0
# 97          97   6.7  182.0          1
# 98          98   6.3  103.0          1
# 99          99   6.2  113.0          1
#
# [100 rows x 4 columns]

# %%
df.iloc[:,1:]
# Out:
#     cgpa     iq  placement
# 0    6.8  123.0          1
# 1    5.9  106.0          0
# 2    5.3  121.0          0
# 3    7.4  132.0          1
# 4    5.8  142.0          0
# ..   ...    ...        ...
# 95   4.3  200.0          0
# 96   4.4   42.0          0
# 97   6.7  182.0          1
# 98   6.3  103.0          1
# 99   6.2  113.0          1
#
# [100 rows x 3 columns]

# %%
df = df.iloc[ : ,1:]

# %%
df
# Out:
#     cgpa     iq  placement
# 0    6.8  123.0          1
# 1    5.9  106.0          0
# 2    5.3  121.0          0
# 3    7.4  132.0          1
# 4    5.8  142.0          0
# ..   ...    ...        ...
# 95   4.3  200.0          0
# 96   4.4   42.0          0
# 97   6.7  182.0          1
# 98   6.3  103.0          1
# 99   6.2  113.0          1
#
# [100 rows x 3 columns]

# %%
df.head()
# Out:
#    cgpa     iq  placement
# 0   6.8  123.0          1
# 1   5.9  106.0          0
# 2   5.3  121.0          0
# 3   7.4  132.0          1
# 4   5.8  142.0          0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   cgpa       100 non-null    float64
#  1   iq         100 non-null    float64
#  2   placement  100 non-null    int64
# dtypes: float64(2), int64(1)
# memory usage: 2.5 KB

# %%
df.shape
# Out:
# (100, 3)

# %%
df.isnull().sum()
# Out:
# cgpa         0
# iq           0
# placement    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df['cgpa'] ,df['iq'] )

# %%
plt.scatter(df['cgpa'] ,df['iq'] , c=df['placement'] )

# %% [markdown]
# ## Extact input and output cols

# %%
df
# Out:
#     cgpa     iq  placement
# 0    6.8  123.0          1
# 1    5.9  106.0          0
# 2    5.3  121.0          0
# 3    7.4  132.0          1
# 4    5.8  142.0          0
# ..   ...    ...        ...
# 95   4.3  200.0          0
# 96   4.4   42.0          0
# 97   6.7  182.0          1
# 98   6.3  103.0          1
# 99   6.2  113.0          1
#
# [100 rows x 3 columns]

# %% [markdown]
# ### Way one
# - using column names

# %%
x = df[['cgpa' ,'iq']]

# %%
x
# Out:
#     cgpa     iq
# 0    6.8  123.0
# 1    5.9  106.0
# 2    5.3  121.0
# 3    7.4  132.0
# 4    5.8  142.0
# ..   ...    ...
# 95   4.3  200.0
# 96   4.4   42.0
# 97   6.7  182.0
# 98   6.3  103.0
# 99   6.2  113.0
#
# [100 rows x 2 columns]

# %%
y = df['placement']

# %%
y
# Out:
# 0     1
# 1     0
# 2     0
# 3     1
# 4     0
#      ..
# 95    0
# 96    0
# 97    1
# 98    1
# 99    1
# Name: placement, Length: 100, dtype: int64

# %% [markdown]
# ### Way two
# - using index sliceing

# %%
x = df.iloc[ : , 0:2]
x
# Out:
#     cgpa     iq
# 0    6.8  123.0
# 1    5.9  106.0
# 2    5.3  121.0
# 3    7.4  132.0
# 4    5.8  142.0
# ..   ...    ...
# 95   4.3  200.0
# 96   4.4   42.0
# 97   6.7  182.0
# 98   6.3  103.0
# 99   6.2  113.0
#
# [100 rows x 2 columns]

# %%
y = df.iloc[: , -1]
y
# Out:
# 0     1
# 1     0
# 2     0
# 3     1
# 4     0
#      ..
# 95    0
# 96    0
# 97    1
# 98    1
# 99    1
# Name: placement, Length: 100, dtype: int64

# %%
print(df.shape)
print(x.shape)
print(y.shape)
# Out:
# (100, 3)
# (100, 2)
# (100,)

# %% [markdown]
# ## train test split

# %%
from sklearn.model_selection import train_test_split

# %%
x_train ,x_test , y_train , y_test  = train_test_split(x,y,test_size=0.1)

# %%
x_train
# Out:
#     cgpa     iq
# 16   5.2  224.0
# 91   7.5  158.0
# 25   5.0   91.0
# 10   6.0   45.0
# 52   7.0  175.0
# ..   ...    ...
# 56   6.1   65.0
# 3    7.4  132.0
# 19   5.2  132.0
# 80   4.9  196.0
# 7    5.0   63.0
#
# [90 rows x 2 columns]

# %%
x_test
# Out:
#     cgpa     iq
# 86   5.1  128.0
# 87   5.7  132.0
# 55   7.8  114.0
# 93   6.8  112.0
# 88   4.4  149.0
# 94   4.7   52.0
# 32   7.0  139.0
# 54   6.4  141.0
# 78   6.1   81.0
# 5    7.1   48.0

# %%
y_train
# Out:
# 16    0
# 91    1
# 25    0
# 10    1
# 52    1
#      ..
# 56    0
# 3     1
# 19    0
# 80    0
# 7     0
# Name: placement, Length: 90, dtype: int64

# %%
y_test
# Out:
# 86    0
# 87    1
# 55    1
# 93    1
# 88    0
# 94    0
# 32    1
# 54    1
# 78    0
# 5     1
# Name: placement, dtype: int64

# %% [markdown]
# ### scaling

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
x_train_transform = scaler.fit_transform(x_train)

x_train_transform
# Out:
# array([[-0.67915728,  2.47520668],
#        [ 1.32920782,  0.82284349],
#        [-0.85379772, -0.85455551],
#        [ 0.01940449, -2.00620258],
#        [ 0.89260671,  1.24845219],
#        [ 1.41652804, -0.90462712],
#        [ 0.4560056 ,  0.8729151 ],
#        [-0.67915728, -0.3788752 ],
#        [ 1.15456738, -0.97973454],
#        [-0.15523595,  0.42227059],
#        [ 0.01940449, -0.02837391],
#        [-1.20307861,  0.52241382],
#        [ 0.4560056 , -2.20648903],
#        [ 0.80528649,  0.34716318],
#        [ 1.85312915,  0.59752124],
#        [ 0.80528649, -0.72937648],
#        [ 0.54332582, -0.12851714],
#        [ 0.63064605,  1.42370283],
#        [-0.7664775 , -1.48045066],
#        [-0.85379772, -0.17858875],
#        [ 0.36868538, -0.22866036],
#        [ 1.15456738, -1.88102355],
#        [-1.72699994, -1.2551284 ],
#        [ 1.32920782, -1.60562969],
#        [-1.02843817, -0.32880358],
#        [ 2.20241004, -0.12851714],
#        [-1.02843817,  0.94802252],
#        [-1.02843817,  0.39723479],
#        [-0.94111795,  0.22198415],
#        [-0.67915728, -0.87959132],
#        [ 0.54332582,  0.32212737],
#        [ 0.01940449, -0.57916164],
#        [ 0.89260671,  1.84931153],
#        [-1.11575839, -0.10348133],
#        [ 2.0277696 ,  1.07320155],
#        [-1.37771906, -2.08131   ],
#        [-0.94111795,  0.64759285],
#        [-0.59183706, -0.10348133],
#        [ 0.71796627,  0.39723479],
#        [-0.24255617,  0.4473064 ],
#        [ 1.15456738,  0.29709156],
#        [-0.7664775 ,  1.273488  ],
#        [ 0.89260671, -1.53052227],
#        [ 0.4560056 , -0.87959132],
#        [ 1.85312915,  1.02312994],
#        [-0.50451684, -0.27873197],
#        [-2.16360105,  2.70052893],
#        [-0.50451684,  0.24701995],
#        [ 1.76580893, -1.15498518],
#        [-0.67915728,  0.89795091],
#        [-0.94111795,  0.74773607],
#        [ 0.28136516,  0.0467335 ],
#        [-1.46503928,  1.87434734],
#        [ 0.10672472, -0.55412584],
#        [ 0.71796627, -0.87959132],
#        [ 0.19404494, -0.30376778],
#        [-0.50451684, -0.45398261],
#        [ 0.80528649,  0.32212737],
#        [ 0.28136516, -0.55412584],
#        [-0.94111795, -1.60562969],
#        [ 0.63064605,  0.72270026],
#        [-1.81432017, -0.403911  ],
#        [ 1.32920782,  0.12184092],
#        [-2.3382415 ,  1.44873864],
#        [ 0.01940449, -1.48045066],
#        [-0.24255617,  0.37219898],
#        [-0.59183706, -0.27873197],
#        [ 0.4560056 ,  0.12184092],
#        [ 0.01940449,  0.59752124],
#        [-0.24255617,  1.09823735],
#        [-1.11575839, -0.95469873],
#        [-0.94111795, -0.12851714],
#        [-1.72699994, -0.62923326],
#        [ 0.28136516,  0.07176931],
#        [ 0.97992693,  0.64759285],
#        [ 0.71796627, -0.05340972],
#        [ 1.41652804,  0.07176931],
#        [-0.15523595,  1.02312994],
#        [-0.06791573, -0.47901842],
#        [ 0.10672472,  0.77277188],
#        [-0.50451684,  0.34716318],
#        [ 0.10672472,  0.17191253],
#        [ 0.89260671, -0.32880358],
#        [-1.02843817,  1.09823735],
#        [ 1.15456738, -0.22866036],
#        [ 0.10672472, -1.50548646],
#        [ 1.2418876 ,  0.17191253],
#        [-0.67915728,  0.17191253],
#        [-0.94111795,  1.77420411],
#        [-0.85379772, -1.55555808]])

# %%
x_test_transform = scaler.transform(x_test)

x_test_transform
# Out:
# array([[-0.7664775 ,  0.07176931],
#        [-0.24255617,  0.17191253],
#        [ 1.59116849, -0.27873197],
#        [ 0.71796627, -0.32880358],
#        [-1.37771906,  0.59752124],
#        [-1.11575839, -1.83095194],
#        [ 0.89260671,  0.34716318],
#        [ 0.36868538,  0.39723479],
#        [ 0.10672472, -1.10491357],
#        [ 0.97992693, -1.93109517]])

# %% [markdown]
# ## train the model

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf = LogisticRegression()

# %%
clf.fit(x_train_transform , y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# # Model evalution

# %%
y_pred = clf.predict(x_test)
# Out:
# c:\Users\sidda\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2742: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(

# %%
y_test
# Out:
# 86    0
# 87    1
# 55    1
# 93    1
# 88    0
# 94    0
# 32    1
# 54    1
# 78    0
# 5     1
# Name: placement, dtype: int64

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test , y_pred)
# Out:
# 0.5

# %%
from mlxtend.plotting import plot_decision_region

plot_decision_regions(x_train , y_train.values , clf = clf , legend = 2)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[66], line 1
# ----> 1 from mlxtend.plotting import plot_decision_region
#       3 plot_decision_regions(x_train , y_train.values , clf = clf , legend = 2)
#
# ModuleNotFoundError: No module named 'mlxtend'

# %%
import pickle

# %%
pickle.dump(clf , open('model.pkl' , 'wb'))
