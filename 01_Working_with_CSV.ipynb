# %% [markdown]
# ## Importing Pandas

# %%
import pandas as pd

# %% [markdown]
# ### opening a local csv file

# %%
df = pd.read_csv("dataset.csv")

# %%
df
# Out:
#       user_id  session_id            timestamp           profession  \
# 0       43140        3817  2024-10-27 03:19:50   Software Developer
# 1        9263       89304  2023-11-19 05:49:56            Architect
# 2       33655      113595  2023-08-29 17:39:22           HR Manager
# 3       11705      155151  2023-03-18 08:10:46           Accountant
# 4        4384        4358  2023-12-04 14:00:47            Scientist
# ...       ...         ...                  ...                  ...
# 4995    17144       22133  2023-04-08 13:24:06              Student
# 4996    49443       64573  2023-05-27 00:23:04            Professor
# 4997     3097      198064  2023-02-10 17:37:03  Mechanical Engineer
# 4998    42128      170752  2023-03-21 16:00:17           HR Manager
# 4999     4210      181799  2023-02-18 12:42:52             YouTuber
#
#                tool          use_case  iterations prompt_complexity  \
# 0           ChatGPT      Blog Writing           5               low
# ...

# %% [markdown]
# ### Opening a csv file from url

# %% [markdown]
# import requests
# from io import StringIO
#
# url = ""
# headers = {"User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10.14; rv:66.0) Gecko/20100101 Firefox/66.0"}
# req = requests.get(url, headers=headers)
# data = StringIO(req.text)
#
# pd.read_csv(data)

# %%
import requests
from io import StringIO

url = "https://raw.githubusercontent.com/cs109/2014_data/master/countries.csv"
headers = {"User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10.14; rv:66.0) Gecko/20100101 Firefox/66.0"}
req = requests.get(url, headers=headers)
data = StringIO(req.text)

pd.read_csv(data)
# Out:
#        Country         Region
# 0      Algeria         AFRICA
# 1       Angola         AFRICA
# 2        Benin         AFRICA
# 3     Botswana         AFRICA
# 4      Burkina         AFRICA
# ..         ...            ...
# 189   Paraguay  SOUTH AMERICA
# 190       Peru  SOUTH AMERICA
# 191   Suriname  SOUTH AMERICA
# 192    Uruguay  SOUTH AMERICA
# 193  Venezuela  SOUTH AMERICA
#
# [194 rows x 2 columns]

# %%
import requests
import pandas as pd
from io import StringIO

url = "https://raw.githubusercontent.com/cs109/2014_data/master/countries.csv"
headers = {"User-Agent": "Mozilla/5.0"}
req = requests.get(url, headers=headers)
data = StringIO(req.text)

df_countries = pd.read_csv(data)

# Save to CSV locally
df_countries.to_csv("countries.csv", index=False)

# %% [markdown]
# ## Sep Parameter

# %%
pd.read_csv('movie_titles_metadata.tsv')
# Out:
#     m0\t10 things i hate about you\t1999\t6.90\t62847\t['comedy' 'romance']
# 0    m1\t1492: conquest of paradise\t1992\t6.20\t10...
# 1    m2\t15 minutes\t2001\t6.10\t25854\t['action' '...
# 2    m3\t2001: a space odyssey\t1968\t8.40\t163227\...
# 3    m4\t48 hrs.\t1982\t6.90\t22289\t['action' 'com...
# 4    m5\tthe fifth element\t1997\t7.50\t133756\t['a...
# ..                                                 ...
# 611  m612\twatchmen\t2009\t7.80\t135229\t['action' ...
# 612  m613\txxx\t2002\t5.60\t53505\t['action' 'adven...
# 613  m614\tx-men\t2000\t7.40\t122149\t['action' 'sc...
# 614  m615\tyoung frankenstein\t1974\t8.00\t57618\t[...
# 615  m616\tzulu dawn\t1979\t6.40\t1911\t['action' '...
#
# [616 rows x 1 columns]

# %%
# sep='parameter' , seperates the baced on the delimitor , in csv , comma is default , 

pd.read_csv('movie_titles_metadata.tsv' , sep='\t')
# Out:
#        m0  10 things i hate about you  1999  6.90     62847  \
# 0      m1  1492: conquest of paradise  1992   6.2   10421.0
# 1      m2                  15 minutes  2001   6.1   25854.0
# 2      m3       2001: a space odyssey  1968   8.4  163227.0
# 3      m4                     48 hrs.  1982   6.9   22289.0
# 4      m5           the fifth element  1997   7.5  133756.0
# ..    ...                         ...   ...   ...       ...
# 611  m612                    watchmen  2009   7.8  135229.0
# 612  m613                         xxx  2002   5.6   53505.0
# 613  m614                       x-men  2000   7.4  122149.0
# 614  m615          young frankenstein  1974   8.0   57618.0
# 615  m616                   zulu dawn  1979   6.4    1911.0
#
#                                   ['comedy' 'romance']
# 0          ['adventure' 'biography' 'drama' 'history']
# 1                ['action' 'crime' 'drama' 'thriller']
# 2                     ['adventure' 'mystery' 'sci-fi']
# ...

# %%
# names = [ list column names] , used to add column names

pd.read_csv('movie_titles_metadata.tsv' , sep='\t' , names=["sno" , 'Title','Year' , 'Rating' , "Votes" ,'Geners' ])
# Out:
#       sno                       Title  Year  Rating     Votes  \
# 0      m0  10 things i hate about you  1999     6.9   62847.0
# 1      m1  1492: conquest of paradise  1992     6.2   10421.0
# 2      m2                  15 minutes  2001     6.1   25854.0
# 3      m3       2001: a space odyssey  1968     8.4  163227.0
# 4      m4                     48 hrs.  1982     6.9   22289.0
# ..    ...                         ...   ...     ...       ...
# 612  m612                    watchmen  2009     7.8  135229.0
# 613  m613                         xxx  2002     5.6   53505.0
# 614  m614                       x-men  2000     7.4  122149.0
# 615  m615          young frankenstein  1974     8.0   57618.0
# 616  m616                   zulu dawn  1979     6.4    1911.0
#
#                                                 Geners
# 0                                 ['comedy' 'romance']
# 1          ['adventure' 'biography' 'drama' 'history']
# ...

# %% [markdown]
# ## Index_col parameter

# %%
pd.read_csv('aug_train.csv')
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920   Male
# 1            29725   city_40                   0.776   Male
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767   Male
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# ...

# %%
pd.read_csv('aug_train.csv' , index_col='enrollee_id')
# Out:
#                  city  city_development_index gender      relevent_experience  \
# enrollee_id
# 8949         city_103                   0.920   Male  Has relevent experience
# 29725         city_40                   0.776   Male   No relevent experience
# 11561         city_21                   0.624    NaN   No relevent experience
# 33241        city_115                   0.789    NaN   No relevent experience
# 666          city_162                   0.767   Male  Has relevent experience
# ...               ...                     ...    ...                      ...
# 7386         city_173                   0.878   Male   No relevent experience
# 31398        city_103                   0.920   Male  Has relevent experience
# 24576        city_103                   0.920   Male  Has relevent experience
# 5756          city_65                   0.802   Male  Has relevent experience
# 23834         city_67                   0.855    NaN   No relevent experience
#
# ...

# %% [markdown]
# ## Header Parameter

# %%
pd.read_csv("dataset.csv")
# Out:
#       user_id  session_id            timestamp           profession  \
# 0       43140        3817  2024-10-27 03:19:50   Software Developer
# 1        9263       89304  2023-11-19 05:49:56            Architect
# 2       33655      113595  2023-08-29 17:39:22           HR Manager
# 3       11705      155151  2023-03-18 08:10:46           Accountant
# 4        4384        4358  2023-12-04 14:00:47            Scientist
# ...       ...         ...                  ...                  ...
# 4995    17144       22133  2023-04-08 13:24:06              Student
# 4996    49443       64573  2023-05-27 00:23:04            Professor
# 4997     3097      198064  2023-02-10 17:37:03  Mechanical Engineer
# 4998    42128      170752  2023-03-21 16:00:17           HR Manager
# 4999     4210      181799  2023-02-18 12:42:52             YouTuber
#
#                tool          use_case  iterations prompt_complexity  \
# 0           ChatGPT      Blog Writing           5               low
# ...

# %%
## header makes a specified row as column names 

pd.read_csv("dataset.csv" , header=1)
# Out:
#       43140    3817  2024-10-27 03:19:50   Software Developer        ChatGPT  \
# 0      9263   89304  2023-11-19 05:49:56            Architect  Perplexity AI
# 1     33655  113595  2023-08-29 17:39:22           HR Manager   Grammarly AI
# 2     11705  155151  2023-03-18 08:10:46           Accountant         Claude
# 3      4384    4358  2023-12-04 14:00:47            Scientist         Gemini
# 4     28467  113897  2024-07-02 10:26:29     Business Analyst       Canva AI
# ...     ...     ...                  ...                  ...            ...
# 4994  17144   22133  2023-04-08 13:24:06              Student      Cursor AI
# 4995  49443   64573  2023-05-27 00:23:04            Professor      Cursor AI
# 4996   3097  198064  2023-02-10 17:37:03  Mechanical Engineer     Midjourney
# 4997  42128  170752  2023-03-21 16:00:17           HR Manager         DALL-E
# 4998   4210  181799  2023-02-18 12:42:52             YouTuber        AutoGPT
#
# ...

# %% [markdown]
# ## Use_columns Parameter

# %%
pd.read_csv("aug_train.csv")
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920   Male
# 1            29725   city_40                   0.776   Male
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767   Male
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# ...

# %%
## in usecolumns we can specify the columns that we only wanted

pd.read_csv('aug_train.csv' , usecols=['enrollee_id' , 'gender' , 'relevent_experience'])
# Out:
#        enrollee_id gender      relevent_experience
# 0             8949   Male  Has relevent experience
# 1            29725   Male   No relevent experience
# 2            11561    NaN   No relevent experience
# 3            33241    NaN   No relevent experience
# 4              666   Male  Has relevent experience
# ...            ...    ...                      ...
# 19153         7386   Male   No relevent experience
# 19154        31398   Male  Has relevent experience
# 19155        24576   Male  Has relevent experience
# 19156         5756   Male  Has relevent experience
# 19157        23834    NaN   No relevent experience
#
# [19158 rows x 3 columns]

# %% [markdown]
# ## squeeze parameter

# %%
df = pd.read_csv('aug_train.csv', usecols=['gender'])
gender_series = df['gender']

df
# Out:
#       gender
# 0       Male
# 1       Male
# 2        NaN
# 3        NaN
# 4       Male
# ...      ...
# 19153   Male
# 19154   Male
# 19155   Male
# 19156   Male
# 19157    NaN
#
# [19158 rows x 1 columns]

# %%
gender_series
# Out:
# 0        Male
# 1        Male
# 2         NaN
# 3         NaN
# 4        Male
#          ...
# 19153    Male
# 19154    Male
# 19155    Male
# 19156    Male
# 19157     NaN
# Name: gender, Length: 19158, dtype: object

# %% [markdown]
# ## Skiprows / nrows parameters

# %%
pd.read_csv('aug_train.csv')
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920   Male
# 1            29725   city_40                   0.776   Male
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767   Male
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# ...

# %%
pd.read_csv("aug_train.csv" , skiprows=[1,2,3,4,5]) # skiprows skips specified rows and desplays remaining all rows
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0            21651  city_176                   0.764    NaN
# 1            28806  city_160                   0.920   Male
# 2              402   city_46                   0.762   Male
# 3            27107  city_103                   0.920   Male
# 4              699  city_103                   0.920    NaN
# ...            ...       ...                     ...    ...
# 19148         7386  city_173                   0.878   Male
# 19149        31398  city_103                   0.920   Male
# 19150        24576  city_103                   0.920   Male
# 19151         5756   city_65                   0.802   Male
# 19152        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience    Part time course        Graduate
# 1      Has relevent experience       no_enrollment     High School
# ...

# %%
pd.read_csv('aug_train.csv' , nrows=100) #nrows takes only limited n no of rows of data
# Out:
#     enrollee_id      city  city_development_index gender  \
# 0          8949  city_103                   0.920   Male
# 1         29725   city_40                   0.776   Male
# 2         11561   city_21                   0.624    NaN
# 3         33241  city_115                   0.789    NaN
# 4           666  city_162                   0.767   Male
# ..          ...       ...                     ...    ...
# 95        12081   city_65                   0.802   Male
# 96         7364  city_160                   0.920    NaN
# 97        11184   city_74                   0.579    NaN
# 98         7016   city_65                   0.802   Male
# 99         8695   city_11                   0.550   Male
#
#         relevent_experience enrolled_university education_level  \
# 0   Has relevent experience       no_enrollment        Graduate
# 1    No relevent experience       no_enrollment        Graduate
# 2    No relevent experience    Full time course        Graduate
# ...

# %% [markdown]
# ## loading a huge dataset into chunks

# %%
dfs = pd.read_csv("aug_train.csv" , chunksize=5000)

# %%
dfs

# %%
for chunks in dfs:
    print(chunks.shape)
    print(chunks.size)
# Out:
# (5000, 14)
# 70000
# (5000, 14)
# 70000
# (5000, 14)
# 70000
# (4158, 14)
# 58212

# %%
for i in dfs:
    print(i)
# Out:
#       enrollee_id      city  city_development_index  gender  \
# 0            8949  city_103                   0.920    Male
# 1           29725   city_40                   0.776    Male
# 2           11561   city_21                   0.624     NaN
# 3           33241  city_115                   0.789     NaN
# 4             666  city_162                   0.767    Male
# ...           ...       ...                     ...     ...
# 4995         7892   city_21                   0.624  Female
# 4996        19768   city_21                   0.624    Male
# 4997        33180   city_16                   0.910    Male
# 4998        13215  city_103                   0.920  Female
# 4999         2386   city_21                   0.624    Male
#
#           relevent_experience enrolled_university education_level  \
# 0     Has relevent experience       no_enrollment        Graduate
# 1      No relevent experience       no_enrollment        Graduate
# ...
